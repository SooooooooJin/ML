# %% [markdown]
#  *--------------------------------------------------------------------------------------------------------------------------*
#
#  *------------------------------------------- 2026학년도 1학기 AI신약기초프로그래밍 과제 ---------------------------------------*
#
# *----------------------------------------------------------------------------------------------------------------------------*
#
# 학번 :
#
# 이름 :
#
# 학과 :
#
#
# *-----------------------------------------------------------------------------------------------------------------------*

# %% [markdown]
# > **다음은 파이썬 프로그래밍에 대한 과제용 문제 입니다 (총 20점)**
#
#
#
# > **문제를 잘 읽고**
# **1. 알맞은 코딩 내용을 작성하고,**
# **2. 왜 해당 코딩을 그렇게 작성하였는지 서술하고,**
# **3. 이에 따른 결과도 출력하여**
#
#   1, 2, 3을 함께 제출하시기 바랍니다
#
#
#
#
# *-----------------------------------------------------------------------------------------------------------------------*

# %% [markdown]
# 🔽프로그래밍 과제 문제 1번 (2점)
#
# * 사용자가 1부터 45까지의 정수 7개를 입력하고, 컴퓨터는 1부터 45까지의 난수 7개를 발생합니다.
# *  사용자 정수와 컴퓨터 정수를 비교해서 일차하지 않는 숫자를 출력하는 프로그램을 만들어 봅니다.
#
# ✅ 요구사항:
# 1. 난수 생성시 random 함수를 사용하세요.
# 2. 비교해서 일치하지 않는 숫자는 모두 하나의 배열로 합쳐서 출력하세요.
#
#
#
# 입력 예시 :
# user = [1,2,3,4,5,6,7]
# computer = [1,2,3,13,14,15,16]
#
# 결과: [4,5,6,7,13,14,15,16]

# %%
# 프로그래밍 문제 1번 답 작성란

# %% [markdown]
# 🔽프로그래밍 과제 문제 2번 (2점)
#
# * 사용자가 양의 정수 n을 입력하였을 때, 각 자리의 숫자를 모두 더한 값을 재귀 함수로 구해봅시다.
#
# ✅ 요구사항:
# 1. 반드시 재귀적으로 호출되는 함수를 사용하세요.
# 2. n의 입력범위는 0 ≤ n ≤ 10,000 까지 이며, 그 외의 값이 입력되면 '계산할 수 없음' 을 출력하세요.
#
#
# 입력 예시 :
# n = 4725
#
# 결과: 4 + 7 + 2 + 5 = 18

# %%
# 프로그래밍 문제 2번 답 작성란

# %% [markdown]
# 🔽프로그래밍 과제 문제 3번 (2점)
#
# * 사용자가 양의 정수들 n개를 입력하였을 때, 이를 정수 리스트 numbers로 저장하고, 재귀를 이용하여 numbers의 최댓값을 구해보세요.
#
# ✅ 요구사항:
# 1. max() 함수의 사용을 금지합니다 .
# 2. 반드시 재귀적으로 호출되는 함수를 사용합니다.
# 3. 리스트에는 최소 1개의 값이 존재해야 합니다. (1 ≤ n ≤ 10)
#
# 입력 예시 :
# numbers = [1,3,4,6,11,4]
# 결과: 11

# %%
# 프로그래밍 문제 3번 답 작성란

# %% [markdown]
# 🔽프로그래밍 과제 문제 4번 (2점)
#
# * 사용자가 문자열 n개를 입력하였을 때, 이를 단어 리스트 words로 저장하고, 각 단어가 몇 번 등장했는지 딕셔너리를 이용하여 계산하는 함수를 작성하세요.
#
# ✅ 요구사항:
# 1. count() 함수의 사용을 금지합니다 .
# 2. collections 모듈 사용을 금지합니다.
# 3. 리스트에는 최소 1개의 값이 존재해야 합니다. (1 ≤ n ≤ 10)
#
# 입력 예시 :
# words = ['a', 'b', 'c', 'a', 'b', 'c']
# 결과: {'a':2, 'b':2, 'c':2}

# %%
# 프로그래밍 문제 4번 답 작성란

# %% [markdown]
# 🔽프로그래밍 과제 문제 5번 (4점)
#
# * 단어 s의 가운데 글자를 반환하는 함수인 solution을 만들어 보세요.
# * 단어의 길이가 짝수라면 가운데 두글자를 반환하면 됩니다.
# * 단어는 사용자에게 입력받으며, 요구사항에 어긋날 경우, '처리할수 없음' 을 반환합니다.
#
# ✅ 요구사항: s는 길이가 1이상, 100 이하인 문자열 데이터를 가정합니다.
#
#
#
# * 입출력 예시 1 : 단어 s 가 'abcde' 일 경우, return 값은 'c'
# * 입출력 예시 2 : 단어 s 가 'qwer' 일 경우, return 값은 'we'

# %%
# 프로그래밍 문제 5번 답 작성란

# %% [markdown]
# 🔽프로그래밍 문제 6번 (4점)
#
#
# * 덕성여자중학교에 다니는 학생들은 각자 정수 번호를 갖고 있습니다.
# * 이 학교 학생 3명의 정수 번호를 더했을 때 0이 되면 3명의 학생은 삼총사라고 합니다.
# * 예를 들어, 5명의 학생이 있고, 각각의 정수 번호가 순서대로 -2, 3, 0, 2, -5일 때, 첫 번째, 세 번째, 네 번째 학생의 정수 번호를 더하면 0이므로 세 학생은 삼총사입니다.
# * 또한, 두 번째, 네 번째, 다섯 번째 학생의 정수 번호를 더해도 0이므로 세 학생도 삼총사입니다. 따라서 이 경우 덕성여자중학교에서는 두 가지 방법으로 삼총사를 만들 수 있습니다.
#
# * 덕성여자중학생들의 번호를 나타내는 정수 배열 number가 매개변수로 주어질 때, 학생들 중 삼총사를 만들 수 있는 방법의 수를 반환하도록 solution 함수를 완성하세요.
#
#
# ✅ 요구사항:
# 1. 3 ≤ number의 길이 ≤ 10
# 2. -100 ≤ number의 각 원소 ≤ 100
# 3. 서로 다른 학생의 정수 번호가 같을 수 있습니다.
# 4. number의 각 원소를 생성할 때는 난수 생성함수인 random 모듈을 사용합니다.

# %%
# 프로그래밍 문제 6번 답 작성란

# %% [markdown]
# 🔽프로그래밍 문제 7번 (4점)
#
# 오래전에 유행했던 콜라 문제가 있습니다. 지문은 다음과 같습니다.
#
# *  콜라 빈 병 2개를 가져다주면 콜라 1병을 주는 마트가 있다.
# *  빈 병 20개를 가져다주면 몇 병을 받을 수 있는가?
# *  단, 보유 중인 빈 병이 2개 미만이면, 콜라를 받을 수 없다.
#
#
#
# 문제를 풀던 덕성이는 콜라 문제의 완벽한 해답을 찾았습니다. 덕성이가 푼 방법은 아래 그림과 같습니다.
#
# ![image.png](data:image/png;base64,...)
#
# *  우선 콜라 빈 병 20병을 가져가서 10병을 받습니다.
# *  받은 10병을 모두 마신 뒤, 가져가서 5병을 받습니다.
# *  5병 중 4병을 모두 마신 뒤 가져가서 2병을 받고, 또 2병을 모두 마신 뒤 가져가서 1병을 받습니다.
# *  받은 1병과 5병을 받았을 때 남은 1병을 모두 마신 뒤 가져가면 1병을 또 받을 수 있습니다.
# *  이 경우 덕성이는 총 10 + 5 + 2 + 1 + 1 = 19병의 콜라를 받을 수 있습니다.
#
# ----------------------------------------------------------------------------
#
# *  문제를 열심히 풀던 덕성이는 일반화된 콜라 문제를 생각했습니다.
# *  이 문제는 빈 병 a개를 가져다주면 콜라 b병을 주는 마트가 있을 때, 빈 병 n개를 가져다주면 몇 병을 받을 수 있는지 계산하는 문제입니다. 기존 콜라 문제와 마찬가지로, 보유 중인 빈 병이 a개 미만이면, 추가적으로 빈 병을 받을 순 없습니다.
#
# *  덕성이는 열심히 고심했지만, 일반화된 콜라 문제의 답을 찾을 수 없었습니다. 덕성이를 도와, 일반화된 콜라 문제를 해결하는 프로그램을 만들어 주세요.
# *  콜라를 받기 위해 마트에 주어야 하는 병 수 a, 빈 병 a개를 가져다 주면 마트가 주는 콜라 병 수 b, 덕성이가 가지고 있는 빈 병의 개수 n이 매개변수로 주어집니다.
# *  덕성이가 받을 수 있는 콜라의 병 수를 return 하도록 solution 함수를 작성해주세요.
#
#
#   ✅ 요구사항:
# *  1 ≤ b < a ≤ n ≤ 1,000,000
#
# *  정답은 항상 int 범위를 넘지 않게 주어집니다.

# %%
# 프로그래밍 문제 7번 답 작성란
